# %%
import pyarrow.parquet as pa

# %%
table = pa.read_table('tokenized_gujarati_corpus/word_frequencies_top20.parquet')
table
# Out:
# pyarrow.Table
# word: string
# frequency: int64
# ----
# word: [[".","છે",",","અને","આ",...,"હતી","તો","હતો","હતા","નથી"]]
# frequency: [[96827,63146,46822,28565,18318,...,8270,6216,5776,5490,5162]]

# %%
df = table.to_pandas()

# %%
df
# Out:
#     word  frequency
# 0      .      96827
# 1     છે      63146
# 2      ,      46822
# 3    અને      28565
# 4      આ      18318
# 5     કે      16257
# 6     પણ      13070
# 7   માટે      12940
# 8      -      10646
# 9     એક       9998
# 10   કરી       9814
# 11    પર       9669
# 12    તે       8503
# 13     જ       8414
# 14  સાથે       8322
# 15   હતી       8270
# 16    તો       6216
# 17   હતો       5776
# 18   હતા       5490
# 19   નથી       5162
