# %%
import pandas as pd

# %%
input_path = "sentence_tokenizer.parquet"

# Read parquet file
df = pd.read_parquet(input_path)

# %%
print("Columns in parquet:", df.columns)
print(df.head())
# Out:
# Columns in parquet: Index(['original_sentence', 'tokenized_sentence', 'token_count'], dtype='object')
#                                    original_sentence  \
# 0  આ વીડિયો જુઓ: ઊંઝા માર્કેટયાર્ડ આજથી 25 જુલાઈ ...
# 1                             મિથેનોલ આવ્યો ક્યાંથી?
# 2  આખરે ત્રણ રાજ્યોમાં મળેલ હાર પર કોંગ્રેસ અધ્યક...
# 3  તેમણે કહ્યું કે, ત્રિપુરા, નાગાલેન્ડ અને મેઘાલ...
# 4  આ આંકડો માટે, અને વજન ઘટાડવા માટે પ્રકાશનનો દિ...
#
#                                   tokenized_sentence  token_count
# 0  આ વીડિયો જુઓ : ઊંઝા માર્કેટયાર્ડ આજથી 25 જુલાઈ...           11
# 1                            મિથેનોલ આવ્યો ક્યાંથી ?            4
# 2  આખરે ત્રણ રાજ્યોમાં મળેલ હાર પર કોંગ્રેસ અધ્યક...           17
# 3  તેમણે કહ્યું કે , ત્રિપુરા , નાગાલેન્ડ અને મેઘ...           25
# 4  આ આંકડો માટે , અને વજન ઘટાડવા માટે પ્રકાશનનો દ...           21
